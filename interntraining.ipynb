# %% [markdown]
# <a href="https://colab.research.google.com/github/MallikarjunPatil24/IT-ignite/blob/main/interntraining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 3, 4])
ypoints = np.array([8,10,7])

plt.plot(xpoints, ypoints, marker = '.', color = 'b',linestyle = 'dotted',linewidth = '5')
plt.show()

# %%
import pandas as pd
import numpy as np

s = pd.Series()
print("Pandas Series: ", s)
data = np.array(['g', 'e', 'e', 'k', 's'])

s = pd.Series(data)
print("Pandas Series:\n", s)
# Out:
# Pandas Series:  Series([], dtype: object)
# Pandas Series:
#  0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object

# %%
import pandas as pd

file_path = '/titanic.csv'

ps = pd.read_csv(file_path)

ps.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
ps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
ps.sample(3)
ps[ps['Sex'] == 'male']
ps[ps['Embarked'] == 'Q']
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 5              6         0       3                      Moran, Mr. James
# 16            17         0       3                  Rice, Master. Eugene
# 22            23         1       3           McGowan, Miss. Anna "Annie"
# 28            29         1       3         O'Dwyer, Miss. Ellen "Nellie"
# 32            33         1       3              Glynn, Miss. Mary Agatha
# ..           ...       ...     ...                                   ...
# 790          791         0       3              Keane, Mr. Andrew "Andy"
# 825          826         0       3                       Flynn, Mr. John
# 828          829         1       3          McCormack, Mr. Thomas Joseph
# 885          886         0       3  Rice, Mrs. William (Margaret Norton)
# 890          891         0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
ps[ps['PassengerId'] == '17']
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
import matplotlib.pyplot as plt
ps['Embarked'].hist()
plt.show()

# %%
ps['Survived'].mode()
# Out:
# 0    0
# Name: Survived, dtype: int64

# %%
ps.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
ps['Sex'].value_counts().plot(kind='pie')
plt.show()

# %%
color_list = ['yellow', 'blue', 'orange']
ps['Pclass'].value_counts().plot(kind='bar', color=color_list)
plt.show()

# %%
a = 10
b = 40

print(a & b)
print(a | b)
print(~a)
print(a ^ b)
print(a >> 2)
print(a << 2)
# Out:
# 8
# 42
# -11
# 34
# 2
# 40

# %%
def evenOdd(x):
    if (x % 2 == 0):
        return "Even"
    else:
        return "Odd"

print(evenOdd(166))
print(evenOdd(77))
# Out:
# Even
# Odd

# %%
i = int(input("How old are you?: "))
f = float(input("Evaluate 20*2: "))
print("Age=",i)
if(f == 40):
    print(f)
else:
    print("wrong")
# Out:
# How old are you?: 22
# Evaluate 20*2: 40
# Age= 22
# 40.0

# %%
M = "MALLIKARJUNA"
M1 = M.replace("ARJUNA", "arjuna")
print(len(M))
print(M1)
print(M[0])
print(M[9])
print(M[1:9])
print(M[-9])
M = M[:12] + " PATIL"
print(M)
# Out:
# 12
# MALLIKarjuna
# M
# U
# ALLIKARJ
# L
# MALLIKARJUNA PATIL
